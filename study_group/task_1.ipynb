# %%
import pandas as pd
import numpy as np

# %%
with open(r"C:\Users\wu\Desktop\pyt\task_1_zhaopin_data.csv",encoding = "utf-8") as f:
    df1 = pd.read_csv(f)

# %%
df1
# Out:
#                              工作名         薪资  学历要求   工作经验 是否全职  \
# 0                    python开发工程师     8K-10K    大专   1-3年   全职
# 1                    Python开发工程师    15K-30K    本科   3-5年   全职
# 2                    python开发工程师    17K-30K    本科   3-5年   全职
# 3                     python后端开发       薪资面议    本科   1-3年   全职
# 4                    python开发工程师     6K-12K    大专   3-5年   全职
# 5                    Python开发工程师      6K-8K    大专   1年以下   全职
# 6                 IT培训讲师（Python）    10K-12K    本科     不限   全职
# 7          Python安全产品研发工程师G00815    10K-20K    本科   1-3年   全职
# 8             Python后端开发工程师-上海闵行    13K-18K    本科   3-5年   全职
# 9                      Python工程师      6K-8K    大专     不限   全职
# 10                        Python    12K-16K    本科   3-5年   全职
# 11                     Python工程师      6K-8K    大专     不限   全职
# 12                      python开发    10K-17K    本科   3-5年   全职
# 13                  python工程师-上海  12.5K-25K    本科   3-5年   全职
# ...

# %%
#从头部查看数据
df1.head()
# Out:
#            工作名       薪资 学历要求  工作经验 是否全职            公司名  公司类型      公司规模  \
# 0  python开发工程师   8K-10K   大专  1-3年   全职     上海蜗兴科技有限公司    民营    20-99人
# 1  Python开发工程师  15K-30K   本科  3-5年   全职   苏州复鹄电子科技有限公司    民营     20人以下
# 2  python开发工程师  17K-30K   本科  3-5年   全职   上海心莲信息科技有限公司    民营        不限
# 3   python后端开发     薪资面议   本科  1-3年   全职   中软国际科技服务有限公司  上市公司  10000人以上
# 4  python开发工程师   6K-12K   大专  3-5年   全职  三门峡崤云安全服务有限公司    国企    20-99人
#
#                                                 任职要求  其他备注
# 0  任职要求：?1、计算机相关专业大专及以上学历；2、有Python开发经验，熟悉Django、...   NaN
# 1  职位描述：复鹄电子科技有限公司现正集中开发对标美国DAPAR计划，具有革命颠覆性的模拟电路全...   NaN
# 2    1、3年以上Python开发经验，有独立设计大规模数据处理和分析系统的经验和能力；  2...   NaN
# 3  熟练使用python，至少两至三年以上开发经验；熟悉常见python web框架，像djan...   NaN
# 4   岗位职责： 1.项目的架构设计，核心模块的开发工作；  2. 系统需求分析与设计，并负责完...   NaN

# %%
#从尾部查看数据
df1.tail()
# Out:
#                   工作名       薪资 学历要求  工作经验 是否全职                  公司名   公司类型  \
# 527   高级Java开发工程师（03）  15K-20K   本科  3-5年   全职        上海复深蓝软件股份有限公司   上市公司
# 528  Change Developer     薪资面议   本科  1-3年   全职  瑞银企业管理(中国)有限公司无锡分公司   外商独资
# 529             测试工程师  10K-15K   本科  3-5年   全职          深圳市睿服科技有限公司  股份制企业
# 530        大数据审计岗（上海）  20K-40K   本科  3-5年   全职           永辉超市股份有限公司     民营
# 531          高级sas程序员  12K-15K   本科  3-5年   全职           上海盛迪医药有限公司     民营
#
#            公司规模                                               任职要求  其他备注
# 527  1000-9999人    基础编程  1、精通java和sql编程开发，熟悉java常用开发框架和类库  2、深刻...   NaN
# 528    10000人以上  Your role We are looking for a developer to wr...   NaN
# 529    500-999人    岗位职责：   1.参与项目产品的质量保证工作 ；  2.完成项目测试，包括：功能业务测...   NaN
# 530    10000人以上    1、与大数据部合作建立大数据审计平台  2、协助合伙人通过风险评估草拟年度大数据审计发展...   NaN
# 531    100-499人  JobPurpose:1.?????为临床试验项目提供各种类型的数据处理和分析方面的服务，包...   NaN

# %%
#查看前三行数据
df1.head(3)
# Out:
#            工作名       薪资 学历要求  工作经验 是否全职           公司名 公司类型    公司规模  \
# 0  python开发工程师   8K-10K   大专  1-3年   全职    上海蜗兴科技有限公司   民营  20-99人
# 1  Python开发工程师  15K-30K   本科  3-5年   全职  苏州复鹄电子科技有限公司   民营   20人以下
# 2  python开发工程师  17K-30K   本科  3-5年   全职  上海心莲信息科技有限公司   民营      不限
#
#                                                 任职要求  其他备注
# 0  任职要求：?1、计算机相关专业大专及以上学历；2、有Python开发经验，熟悉Django、...   NaN
# 1  职位描述：复鹄电子科技有限公司现正集中开发对标美国DAPAR计划，具有革命颠覆性的模拟电路全...   NaN
# 2    1、3年以上Python开发经验，有独立设计大规模数据处理和分析系统的经验和能力；  2...   NaN

# %%
#查看第三行数据暂无

# %%
df1[["学历要求","工作经验","是否全职"]]
# Out:
#      学历要求   工作经验 是否全职
# 0      大专   1-3年   全职
# 1      本科   3-5年   全职
# 2      本科   3-5年   全职
# 3      本科   1-3年   全职
# 4      大专   3-5年   全职
# 5      大专   1年以下   全职
# 6      本科     不限   全职
# 7      本科   1-3年   全职
# 8      本科   3-5年   全职
# 9      大专     不限   全职
# 10     本科   3-5年   全职
# 11     大专     不限   全职
# 12     本科   3-5年   全职
# 13     本科   3-5年   全职
# 14     本科   3-5年   全职
# 15     本科   3-5年   全职
# 16     本科  5-10年   全职
# 17     本科     不限   全职
# 18     本科   3-5年   全职
# 19     本科   3-5年   全职
# 20     本科   1-3年   全职
# 21     本科  5-10年   全职
# 22     本科   3-5年   全职
# 23     大专   3-5年   全职
# 24     本科   1-3年   全职
# 25     本科   3-5年   全职
# 26     本科   1-3年   全职
# 27     本科   1-3年   全职
# 28     本科   1-3年   全职
# 29     本科   3-5年   全职
# ..    ...    ...  ...
# 502    本科   1-3年   全职
# 503    本科   1-3年   全职
# 504    本科   1-3年   全职
# 505    大专     不限   全职
# 506    本科     不限   全职
# 507    大专   3-5年   全职
# 508    本科   1-3年   全职
# 509    本科   3-5年   全职
# 510    大专   3-5年   全职
# ...

# %%
df2 = df1.set_index("公司名")

# %%
df2
# Out:
#                                                         工作名         薪资  学历要求  \
# 公司名
# 上海蜗兴科技有限公司                                      python开发工程师     8K-10K    大专
# 苏州复鹄电子科技有限公司                                    Python开发工程师    15K-30K    本科
# 上海心莲信息科技有限公司                                    python开发工程师    17K-30K    本科
# 中软国际科技服务有限公司                                     python后端开发       薪资面议    本科
# 三门峡崤云安全服务有限公司                                   python开发工程师     6K-12K    大专
# 上海日同网络科技有限公司                                    Python开发工程师      6K-8K    大专
# 中公教育上海分公司                                    IT培训讲师（Python）    10K-12K    本科
# 上海诺亚金融服务股份有限公司                        Python安全产品研发工程师G00815    10K-20K    本科
# 博彦科技股份有限公司                               Python后端开发工程师-上海闵行    13K-18K    本科
# 上海怡胜信息科技有限公司                                      Python工程师      6K-8K    大专
# 大袖投资(上海)有限公司                                         Python    12K-16K    本科
# ...

# %%
df3 = df2.drop(["其他备注"],axis=1)

# %%
df3
# Out:
#                                                         工作名         薪资  学历要求  \
# 公司名
# 上海蜗兴科技有限公司                                      python开发工程师     8K-10K    大专
# 苏州复鹄电子科技有限公司                                    Python开发工程师    15K-30K    本科
# 上海心莲信息科技有限公司                                    python开发工程师    17K-30K    本科
# 中软国际科技服务有限公司                                     python后端开发       薪资面议    本科
# 三门峡崤云安全服务有限公司                                   python开发工程师     6K-12K    大专
# 上海日同网络科技有限公司                                    Python开发工程师      6K-8K    大专
# 中公教育上海分公司                                    IT培训讲师（Python）    10K-12K    本科
# 上海诺亚金融服务股份有限公司                        Python安全产品研发工程师G00815    10K-20K    本科
# 博彦科技股份有限公司                               Python后端开发工程师-上海闵行    13K-18K    本科
# 上海怡胜信息科技有限公司                                      Python工程师      6K-8K    大专
# 大袖投资(上海)有限公司                                         Python    12K-16K    本科
# ...

# %%
df4 = df3.drop(["上海蜗兴科技有限公司"])

# %%
df4.to_csv(r"C:\Users\wu\Desktop\pyt\task_1_zhaopin_data_update.csv")
